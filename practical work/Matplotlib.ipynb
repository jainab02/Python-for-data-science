# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('pr9.csv')
df
from turtle import color
x='Vehicle Density'
y=['Co2 emission for fixed interval light','Co2 emission for variable interval light']
df.plot(x,y,color=['green','red'],marker='o')
plt.title('Vehicle Desity')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid()
plt.show()

# %%
# df=pd.read_csv('pr9.csv')
# df

# %%
# from turtle import color
# x='Vehicle Density'
# y=['Co2 emission for fixed interval light','Co2 emission for variable interval light']
# df.plot(x,y,color=['green','red'],marker='o')
# plt.title('Vehicle Desity')
# plt.xlabel('x-axis')
# plt.ylabel('y-axis')
# plt.grid()
# plt.show()
# # plt.

# %%
df=pd.DataFrame(df)
x=df['Vehicle Density']
y=df['Co2 emission for fixed interval light']
plt.bar(x,y,color='grey',width=400)
plt.title('Vehicle Density')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
from turtle import title


laptop = ['dell','hp','acer','apple','lenovo']
student=np.array([20,15,7,5,100])
fig = plt.figure(figsize=(5,7))
mycolors=['green','red','grey','pink','blue']
e= [0,0,0.2,0,0.1]
plt.pie(student,labels=laptop,colors=mycolors,autopct='%.0f%%',explode=e)
plt.title("student data")
# plt.legend(title="laptop used by students")
plt.show()
